# %%
# !pip show dpone-datagenie
# Out:
# Name: dpone-datagenie
# Version: 0.1.1
# Summary: Synthetic DataGen is a powerful online library designed to generate synthetic data sets for various use cases. It leverages advanced algorithms and customizable parameters to create realistic data that closely mimics real-world data while ensuring privacy and security.
# Home-page:
# Author: NITISH MISHRA
# Author-email: nitishmishra6057@gmail.com
# License:
# Location: C:\Users\hp\miniconda3\Lib\site-packages
# Requires: imblearn, matplotlib, numpy, pandas, seaborn
# Required-by:

# %%
from dpone_datagenie import supervised_num

# %%
supervised_num.generate_supervised_numerical_dataframe?
# Out:
# Signature:
# supervised_num.generate_supervised_numerical_dataframe(
#     num_samples,
#     num_features,
#     mean=0,
#     std=1,
#     seed=None,
# )
# Docstring:
# Generate a synthetic supervised numerical dataframe.
#
# Parameters:
# - num_samples (int): Number of samples in the dataframe.
# - num_features (int): Number of numerical features in the dataframe.
# - mean (float or array-like, optional): Mean of the normal distribution. Default is 0.
# - std (float or array-like, optional): Standard deviation of the normal distribution. Default is 1.
# - seed (int or None, optional): Seed for random number generation. Default is None.
#
# Returns:
# - df (pandas.DataFrame): Synthetic dataframe with numerical features and labels.
# File:      c:\users\hp\miniconda3\lib\site-packages\dpone_datagenie\supervised_num.py
# Type:      function

# %%
supervised_num.generate_supervised_numerical_dataframe(10, 3, )
# Out:
#    feature_1  feature_2  feature_3  label
# 0   0.198461  -0.129486   0.069106    1.0
# 1  -1.102848  -0.656241  -1.059368    1.0
# 2  -0.114067   2.225993   1.354455    1.0
# 3   0.705738   0.370200  -0.090669    0.0
# 4  -0.527968   0.277279   2.135124    1.0
# 5   0.614906  -0.748670  -0.058526    0.0
# 6  -2.536113   1.617855   1.051715    0.0
# 7   0.468694  -0.203262  -0.893420    1.0
# 8  -0.626596  -0.168402  -0.756287    0.0
# 9   0.202277   1.075300  -1.685933    0.0

# %%
from dpone_datagenie.supervised_mix import generate_supervised_mixed_dataframe

# %%
generate_supervised_mixed_dataframe?
# Out:
# Signature:
# generate_supervised_mixed_dataframe(
#     num_samples,
#     num_numerical_features,
#     num_categorical_features,
#     num_categories_per_feature=3,
#     numerical_mean=0,
#     numerical_std=1,
#     seed=None,
# )
# Docstring:
# Generate a synthetic supervised dataframe with mixed numerical and categorical features.
#
# Parameters:
# - num_samples (int): Number of samples in the dataframe.
# - num_numerical_features (int): Number of numerical features in the dataframe.
# - num_categorical_features (int): Number of categorical features in the dataframe.
# - num_categories_per_feature (int, optional): Number of categories per categorical feature. Default is 3.
# - numerical_mean (float or array-like, optional): Mean of the normal distribution for numerical features. Default is 0.
# - numerical_std (float or array-like, optional): Standard deviation of the normal distribution for numerical features. Default is 1.
# ...

# %%
df = generate_supervised_mixed_dataframe(1000, 2, 2)

# %%
from dpone_datagenie.plotting import plot_correlation, plot_distribution

# %%
plot_distribution(df)

# %%
plot_correlation(df)
